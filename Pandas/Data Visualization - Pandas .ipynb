# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df1 = pd.read_csv('df1',index_col=0) # Set column0 the index
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %% [markdown]
# # Styles

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
df1['A'].hist(bins=20)

# you can also import seaborn
# Out:
# <AxesSubplot:>

# %%
plt.style.use('dark_background')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('fivethirtyeight')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('ggplot')

# %% [markdown]
# # Plots
#
# * df.plot.area
# * df.plot.bar
# * df.plot.density
# * df.plot.hist
# * df.plot.line
# * df.plot.scatter
# * df.plot.bar
# * df.plot.box
# * df.plot.hexbin
# * df.plot.kde
# * df.plot.pie

# %%
# Method 1
df1['A'].plot(kind='hist',bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Method 2
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Area

# %%
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Bar Plot

# %%
# Categorical datas
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Line Plot

# %%
df1.plot.line(y='B',figsize=(12,3),lw=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Scatter

# %%
df1.plot.scatter(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %% [markdown]
# use c to color based off another column value(3D Plot)
# Use cmap to indicate colormap to use.
# For all the colormaps, check out: http://matplotlib.org/users/colormaps.html

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='magma')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %% [markdown]
# use s to indicate size based off another column. s parameter needs to be an array, not just the name of a column:

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %% [markdown]
# ## Box Plot

# %%
df2.plot.box()
# Can also pass a by= argument for groupby
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Hexagonal Bin Plot

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
df
# Out:
#             a         b
# 0    0.131628  1.404196
# 1    1.512274 -0.080650
# 2    0.108274  0.560819
# 3   -0.353374 -0.914344
# 4   -0.161482 -0.950441
# ..        ...       ...
# 995  1.500322  0.057179
# 996  0.465548  0.849654
# 997  1.302865  0.228010
# 998 -0.898872 -1.114210
# 999 -1.919555 -1.203066
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# ## Kernel Density Estimation (KDE)

# %%
df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
