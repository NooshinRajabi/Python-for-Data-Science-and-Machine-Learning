# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic1 = sns.load_dataset('titanic')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# c:\users\asus\appdata\local\programs\python\python38\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# c:\users\asus\appdata\local\programs\python\python38\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1239         """Send a complete request to the server."""
# -> 1240         self._send_request(method, url, body, headers, encode_chunked)
#    1241
#
# c:\users\asus\appdata\local\programs\python\python38\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1285             body = _encode(body, 'body')
# ...
